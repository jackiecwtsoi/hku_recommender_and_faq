# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Dataset Preparation

# %% [markdown]
# ## HKU Dataset

# %%
# define dataset path
CURRICULUM_DATA_PATH = '../crawlers/closed-ended/curriculum-crawlers/data/'

# %%
# load cs recommender datasets
df_cs_all = pd.read_csv(CURRICULUM_DATA_PATH + 'df_cs_all_course_details_prelim.csv', index_col = 0) # all cs course details
df_cs_profs = pd.read_csv(CURRICULUM_DATA_PATH + 'df_cs_courses_and_professors.csv', index_col = 0) # cs course professors

# %%
df_cs_all.head(3)
# Out:
#    Academic Year  No. of credit(s)  Lecture  Lab session Pre-requisite(s)  \
# 0           2022                 6     32.5          6.5              NaN
# 1           2022                 6     32.5          6.5              NaN
# 2           2022                 6      NaN          NaN              NaN
#
#   Co-requisite(s) Mutually exclusive with  Remarks Course Code  \
# 0             NaN    ENGG1111 or ENGG1330      NaN   COMP1117A
# 1             NaN    ENGG1111 or ENGG1330      NaN   COMP1117B
# 2             NaN    COMP1117 or ENGG1111      NaN   ENGG1330A
#
#                                         Course Title  \
# 0  Computer Programming (ActSc, AppAI, DA, IS, Mi...
# 1  Computer Programming (Quant Fin, DA, Minor, 2n...
# 2                   Computer Programming I (A1 - M2)
#
#                                   Course Description  \
# 0  This is an introductory course in computer pro...
# 1  This is an introductory course in computer pro...
# 2  This is an introductory course designed for fi...
#
#                                    Learning Outcomes  \
# 0  [Computational mind]  Able to identify possibl...
# 1  [Computational mind]  Able to identify possibl...
# 2  [Computational mind] Able to identify possible...
#
#    Continuous Assessment Weighting in final course grade (%)  \
# 0                                               50.0
# 1                                               50.0
# 2                                               70.0
#
#    Written Examination Weighting in final course grade (%)  Tutorial  Other  \
# 0                                               50.0             NaN    NaN
# 1                                               50.0             NaN    NaN
# 2                                               30.0            26.0   13.0
#
#   Recommended Learning Hours  Self-study & practical modules Choi Loretta
# 0                        NaN                             NaN          NaN
# 1                        NaN                             NaN          NaN
# 2                        NaN                             NaN          NaN

# %%
# load science recommender datasets
df_science_all = pd.read_csv(CURRICULUM_DATA_PATH + 'df_science_all_course_details.csv', index_col = 0) # all science course details
df_science_profs = pd.read_csv(CURRICULUM_DATA_PATH + 'df_science_courses_and_professors.csv', index_col = 0) # science course professors
df_science_meta = pd.read_csv(CURRICULUM_DATA_PATH + 'df_science_courses_pre.csv', index_col = 0) # meta table

# %%
# add necessary columns to the 'df_cs_all' dataset
df_cs_all['Offering Department'] = 'Computer Science'

# %%
# extract course content related columns for cs
df_cs_content = df_cs_all[[
    'Offering Department', 'Course Code', 'Course Title', 'Course Description', 'Learning Outcomes'
]]

# %%
df_cs_content.head()
# Out:
#   Offering Department Course Code  \
# 0    Computer Science   COMP1117A
# 1    Computer Science   COMP1117B
# 2    Computer Science   ENGG1330A
# 3    Computer Science   ENGG1340A
# 4    Computer Science   ENGG1340B
#
#                                         Course Title  \
# 0  Computer Programming (ActSc, AppAI, DA, IS, Mi...
# 1  Computer Programming (Quant Fin, DA, Minor, 2n...
# 2                   Computer Programming I (A1 - M2)
# 3                            Computer Programming II
# 4                            Computer Programming II
#
#                                   Course Description  \
# 0  This is an introductory course in computer pro...
# 1  This is an introductory course in computer pro...
# 2  This is an introductory course designed for fi...
# 3  This course covers intermediate to advanced co...
# 4  This course covers intermediate to advanced co...
#
#                                    Learning Outcomes
# 0  [Computational mind]  Able to identify possibl...
# 1  [Computational mind]  Able to identify possibl...
# 2  [Computational mind] Able to identify possible...
# 3  [Programming environment and technologies] Abl...
# 4  [Programming environment and technologies] Abl...

# %%
# add necessary columns to the 'df_science_all' dataset
df_science_all['Course Title'] = df_science_meta['Title'] # add course title column
df_science_all['Course Description'] = df_science_all['Course Contents & Topics'] + ' ' + df_science_all['Course Objectives']

# %%
# extract course content related columns for science
df_science_content = df_science_all[[
    'Offering Department', 'Course Code', 'Course Title', 'Course Description'
]]
df_science_content['Learning Outcomes'] = df_science_all['Course Learning Outcomes']
# Out:
# c:\Users\Kackie\anaconda3\envs\DataScience\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_science_content.head()
# Out:
#    Offering Department Course Code  \
# 0  Biomedical Sciences    BIOC1600
# 1  Biomedical Sciences    BIOC2600
# 2  Biomedical Sciences    BIOC3601
# 3  Biomedical Sciences    BIOC3604
# 4  Biomedical Sciences    BIOC3605
#
#                                         Course Title  \
# 0                       Perspectives in biochemistry
# 1                                 Basic biochemistry
# 2                                   Basic metabolism
# 3  Essential techniques in biochemistry and molec...
# 4                            Sequence bioinformatics
#
#                                   Course Description  \
# 0  A Biochemical Perspective on the Basic Science...
# 1  Structure and functions of carbohydrates, lipi...
# 2  This course focuses on the central metabolic p...
# 3  Basic concepts in experimental science; writin...
# 4  This course will introduce and discuss the fol...
#
#                                    Learning Outcomes
# 0  describe the basics of biomolecular structure ...
# 1  relate the structures to functions of major bi...
# 2  achieve a vigorous intellectual appreciation o...
# 3  describe and explain the principles underlying...
# 4  search and retrieve sequence data from biologi...

# %%
# combine both cs and science datasets for course content info
df_course_content = df_cs_content.append(df_science_content)
df_course_content = df_course_content.reset_index(drop = True)

# %%
# rename
df_course_content = df_course_content.rename(columns={'Offering Department': 'Subject Domain'})

# %%
df_course_content
# Out:
#        Subject Domain Course Code  \
# 0    Computer Science   COMP1117A
# 1    Computer Science   COMP1117B
# 2    Computer Science   ENGG1330A
# 3    Computer Science   ENGG1340A
# 4    Computer Science   ENGG1340B
# ..                ...         ...
# 425   Sci Common Core    CCST9051
# 426   Sci Common Core    CCST9054
# 427   Sci Common Core    CCST9056
# 428   Sci Common Core    CCST9067
# 429   Sci Common Core    CCST9068
#
#                                           Course Title  \
# 0    Computer Programming (ActSc, AppAI, DA, IS, Mi...
# 1    Computer Programming (Quant Fin, DA, Minor, 2n...
# 2                     Computer Programming I (A1 - M2)
# 3                              Computer Programming II
# 4                              Computer Programming II
# ..                                                 ...
# 425  What are We Made of - the Fundamental Nature o...
# 426                  War, Peace, and the Natural World
# 427             The Force is with You: How Things Work
# 428                 Leaving Earth: Our Future in Space
# 429       Artificial Intelligence: Utopia or Dystopia?
#
#                                     Course Description  \
# 0    This is an introductory course in computer pro...
# 1    This is an introductory course in computer pro...
# 2    This is an introductory course designed for fi...
# 3    This course covers intermediate to advanced co...
# 4    This course covers intermediate to advanced co...
# ..                                                 ...
# 425                                                NaN
# 426                                                NaN
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
#
#                                      Learning Outcomes
# 0    [Computational mind]  Able to identify possibl...
# 1    [Computational mind]  Able to identify possibl...
# 2    [Computational mind] Able to identify possible...
# 3    [Programming environment and technologies] Abl...
# 4    [Programming environment and technologies] Abl...
# ..                                                 ...
# 425                                                NaN
# 426                                                NaN
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
#
# [430 rows x 5 columns]

# %%
# save dataset to local
df_course_content.to_csv('data/df_course_content_with_domain.csv')

# %% [markdown]
# ## UIUC Dataset

# %%
# load raw UIUC dataset from local
df_uiuc = pd.read_csv('data/uiuc-courses-2022-sp.csv')

# %%
# define a list of subjects to consider for the UIUC dataset
uiuc_subjects_to_consider = [
    'CS', 'IS', # cs and data science
    'ABE', 'BIOC', 'BSE', 'CDB', 'CHBE', 'IB', 'MCB', 'MICR', 'PATH', # biology
    'CHEM', # chemistry
    'PHYS', # physics
    'FSHN', 'NUTR', # nutritional science
    'ESE', 'GEOL', 'ENSU', 'ENVS', 'NRES',
    'STAT', 'ASRM',
    'CS', 'CSE',
    'MATH'
]

# %%
# select the course description columns
df_uiuc_course_content = df_uiuc[[
    'Subject', 'Number', 'Name', 'Description'
]]

# %%
# drop any duplicates
df_uiuc_course_content = df_uiuc_course_content.drop_duplicates()

# %%
# select only the relevant subjects
df_uiuc_course_content = df_uiuc_course_content.loc[df_uiuc_course_content['Subject'].isin(uiuc_subjects_to_consider)]

# %%
# reset index
df_uiuc_course_content = df_uiuc_course_content.reset_index(drop=True)

# %%
# map the different subject codes into different subject domains
uiuc_subjects_dict = {}

for key in ['CS', 'IS']:
    uiuc_subjects_dict[key] = 'Computer Science'
for key in ['ABE', 'BIOC', 'BSE', 'CDB', 'CHBE', 'IB', 'MCB', 'MICR', 'PATH']:
    uiuc_subjects_dict[key] = 'Biology'
for key in ['CHEM']:
    uiuc_subjects_dict[key] = 'Chemistry'
for key in ['PHYS']:
    uiuc_subjects_dict[key] = 'Physics'
for key in ['FSHN', 'NUTR']:
    uiuc_subjects_dict[key] = 'Nutritional Science'
for key in ['ESE', 'GEOL', 'ENSU', 'ENVS', 'NRES']:
    uiuc_subjects_dict[key] = 'Earth Sciences'
for key in ['STAT', 'ASRM']:
    uiuc_subjects_dict[key] = 'Statistics & Actuarial Science'
for key in ['MATH']:
    uiuc_subjects_dict[key] = 'Mathematics'

# %%
# add 'Subject Domain' column to the UIUC dataset based on the subject codes
df_uiuc_course_content['Subject Domain'] = df_uiuc_course_content['Subject'].map(uiuc_subjects_dict)

# %%
df_uiuc_course_content.head()
# Out:
#   Subject  Number                             Name  \
# 0     ABE     141       ABE Principles: Biological
# 1     ABE     152  Water in the Global Environment
# 2     ABE     199       Undergraduate Open Seminar
# 3     ABE     225   ABE Principles: Bioenvironment
# 4     ABE     226    ABE Principles: Bioprocessing
#
#                                          Description Subject Domain
# 0  Principles of biology relevant to agriculture,...        Biology
# 1  This course develops a comprehensive understan...        Biology
# 2          May be repeated to a maximum of 12 hours.        Biology
# 3  Principles of environmental control for biolog...        Biology
# 4  Principles of bioprocess engineering applied t...        Biology

# %%
# convert the columns into the same columns as the HKU dataset
df_uiuc_course_content['Course Code'] = df_uiuc_course_content['Subject'] + df_uiuc_course_content['Number'].apply(lambda x: str(x))
df_uiuc_course_content = df_uiuc_course_content.rename(columns = {
    'Name': 'Course Title',
    'Description': 'Course Description'
})
df_uiuc_course_content = df_uiuc_course_content.drop(columns=['Subject', 'Number'])

# %%
df_uiuc_course_content
# Out:
#                         Course Title  \
# 0         ABE Principles: Biological
# 1    Water in the Global Environment
# 2         Undergraduate Open Seminar
# 3     ABE Principles: Bioenvironment
# 4      ABE Principles: Bioprocessing
# ..                               ...
# 792             Topics in Statistics
# 793       Hierarchical Linear Models
# 794    Individual Study and Research
# 795                  STAT Internship
# 796                  Thesis Research
#
#                                     Course Description  \
# 0    Principles of biology relevant to agriculture,...
# 1    This course develops a comprehensive understan...
# 2            May be repeated to a maximum of 12 hours.
# 3    Principles of environmental control for biolog...
# 4    Principles of bioprocess engineering applied t...
# ..                                                 ...
# 792  May be repeated if topics vary. Prerequisite: ...
# 793       Same as PSYC 587 and EPSY 587. See EPSY 587.
# 794  Directed reading and research. Approved for le...
# 795  Supervised, off-campus experience in a field i...
# 796  Approved for S/U grading only. May be repeated...
#
#                      Subject Domain Course Code
# 0                           Biology      ABE141
# 1                           Biology      ABE152
# 2                           Biology      ABE199
# 3                           Biology      ABE225
# 4                           Biology      ABE226
# ..                              ...         ...
# 792  Statistics & Actuarial Science     STAT578
# 793  Statistics & Actuarial Science     STAT587
# 794  Statistics & Actuarial Science     STAT590
# 795  Statistics & Actuarial Science     STAT593
# 796  Statistics & Actuarial Science     STAT599
#
# [797 rows x 4 columns]

# %%
# save dataset to local
df_uiuc_course_content.to_csv('data/df_uiuc_course_content_with_domain.csv')

# %% [markdown]
# ## HKU + UIUC Dataset

# %%
# combine both HKU and UIUC datasets
df = df_course_content.append(df_uiuc_course_content)

# %%
df = df.reset_index(drop=True)

# %%
# save dataset to local
df.to_csv('data/hku_uiuc_course_content_with_domain.csv')

# %%
# combine the course descriptions and outcomes
df_course_description = df[['Course Description', 'Subject Domain']]

# drop any duplicates
df_course_description = df_course_description.dropna().drop_duplicates().reset_index(drop=True)

# %%
# save dataset to local
df_course_description.to_csv('data/df_hku_uiuc_course_description_with_domain.csv')

# %% [markdown]
# # Finding Subject Domain Keywords

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk import word_tokenize
from nltk import sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Kackie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kackie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Kackie\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Kackie\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# load hku + uiuc dataset from local
df_course_description = pd.read_csv('data/df_hku_uiuc_course_description_with_domain.csv', index_col=0)

df_course_description
# Out:
#                                      Course Description  \
# 0     This is an introductory course in computer pro...
# 1     This is an introductory course designed for fi...
# 2     This course covers intermediate to advanced co...
# 3     This course introduces the basic concepts of f...
# 4     This course introduces concepts and applicatio...
# ...                                                 ...
# 1138  May be repeated if topics vary. Prerequisite: ...
# 1139       Same as PSYC 587 and EPSY 587. See EPSY 587.
# 1140  Directed reading and research. Approved for le...
# 1141  Supervised, off-campus experience in a field i...
# 1142  Approved for S/U grading only. May be repeated...
#
#                       Subject Domain
# 0                   Computer Science
# 1                   Computer Science
# 2                   Computer Science
# 3                   Computer Science
# 4                   Computer Science
# ...                              ...
# 1138  Statistics & Actuarial Science
# 1139  Statistics & Actuarial Science
# 1140  Statistics & Actuarial Science
# 1141  Statistics & Actuarial Science
# 1142  Statistics & Actuarial Science
#
# [1143 rows x 2 columns]

# %%
# combine all descriptions of a subject domain into one single text instead of sarapate rows
def combine_all_rows_into_one(df_filtered, subject_domain):
    combined_text = ''
    for text in df_filtered:
        combined_text += text + ' '
    
    df_new = pd.DataFrame({'Subject Domain Description': combined_text, 'Subject Domain': subject_domain}, index=[0])
    return df_new

# %%
def combine_descriptions_for_all_subjects(df):
    subject_domains = df['Subject Domain'].unique()

    df_result = pd.DataFrame()
    for subject in subject_domains:
        df_filtered = df.loc[df['Subject Domain'] == subject]['Course Description'].drop_duplicates()
        df_new_row = combine_all_rows_into_one(df_filtered, subject)
        df_result = df_result.append(df_new_row)
    
    df_result = df_result.reset_index(drop=True)

    return df_result

# %%
df_subject_domain_descriptions = combine_descriptions_for_all_subjects(df_course_description)

# %%
df_subject_domain_descriptions
# Out:
#                            Subject Domain Description  \
# 0   This is an introductory course in computer pro...
# 1   A Biochemical Perspective on the Basic Science...
# 2   An issue-based approach will be adopted to ena...
# 3   Topics covered in the course will be:- Finding...
# 4   Topic 1:  Gases: Their Properties and Behaviou...
# 5   - Grammar & vocabulary of modern Chinese\r - T...
# 6   Global climatic systems, climate classificatio...
# 7   The course will cover: Computational science a...
# 8   Topics include: the science in the household a...
# 9   This course aims at increasing students' aware...
# 10  The course will introduce a number of key idea...
# 11  Principles of biology relevant to agriculture,...
# 12  Discusses the evolution of the food system to ...
#
#                     Subject Domain
# 0                 Computer Science
# 1              Biomedical Sciences
# 2              Biological Sciences
# 3                          English
# 4                        Chemistry
# 5                          Chinese
# 6                   Earth Sciences
# 7                      Mathematics
# 8                          Physics
# 9                          Faculty
# 10  Statistics & Actuarial Science
# 11                         Biology
# 12             Nutritional Science

# %%
# save dataset to local
df_subject_domain_descriptions.to_csv('data/df_subject_domain_descriptions.csv')

# %% [markdown]
# Our goal is to match the student's skill(s) with a subject domain, so that the student can have a better idea on what courses to study. Therefore, the following models focus on:
# - Input: A set of phrases / sentences that the student inputs into our chatbot
# - Output: A subject domain classification that best matches with the skills the student has
#
# We will:
# 1. First build a taxonomy of all the skills required for each subject domain (for this part we use an unsupervised method)
#     - TF-IDF
#     - TextRank
#     - TopicRank
#     - YAKE!
#     - KeyBERT
# 2. Second implement a model to match the student's skills with the subject domain (for this part we use supervised learning)

# %% [markdown]
# ## 1. Skills taxonomy for each subject domain (unsupervised model)

# %%
# load dataset from local
df_subject_domain_descriptions = pd.read_csv('data/df_subject_domain_descriptions.csv', index_col=0)

# %% [markdown]
# ### Helper Functions

# %% [markdown]
# #### Helper functions for text preprocessing

# %%
# helper function
# return: LIST of tokenized words
def preprocess(text, with_stopwords=False, lemmatize=True):
    text = text.lower()
    words = word_tokenize(text)
    words = [word for word in words if word.isalpha()]
    if with_stopwords==False:
        stop_words = set(stopwords.words('english'))
        words = [word for word in words if not word in stop_words]
    if lemmatize==True:
        lemmatizer=WordNetLemmatizer()
        words = [lemmatizer.lemmatize(word) for word in words]

    return words

# %%
def lemmatize(text):
    text = text.lower()
    words = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    
    return words

# %%
def stem(text):
    text = text.lower()
    words = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if not word in stop_words]
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]

    return words

# %%
def convert_list_to_sent(words):
    sentence = ' '.join(words)
    return sentence

# %%
def stem_entire_document(document):
    final_text = ''
    stemmed_doc = convert_list_to_sent(stem(document))
    final_text += stemmed_doc + ' '
    return final_text

# %% [markdown]
# #### Helper functions for top k keywords

# %%
# helper function
# get top k keywords based on a specific keyword extraction type
# get top k keywords
from summa import keywords
from yake import KeywordExtractor
from keybert import KeyBERT

def get_top_k_keywords(document, type, k=10):
    if type == 'textrank':
        top_k_keywords = keywords.keywords(document).split('\n')
    elif type == 'yake':
        kw_extractor = KeywordExtractor(lan='en', n=1, top=k)
        top_k_keywords = kw_extractor.extract_keywords(text=document)
        
        # since the extractor returns a tuple, we extract the first element in the tuple only
        top_k_keywords = [x for x, _ in top_k_keywords]

    elif type == 'keybert':
        kw_extractor = KeyBERT('distilbert-base-nli-mean-tokens')
        top_k_keywords = kw_extractor.extract_keywords(document, stop_words='english', top_n=k, use_mmr=True)

    return top_k_keywords

# %%
# helper function
# get top k keywords for ALL SUBJECT DOMAINS based on a specific keyword extraction type (e.g. 'tfidf', 'textrank', ...)
# return: DATAFRAME
def get_top_k_keywords_for_all_subjects(df, type, k=10):
    subject_domains = df['Subject Domain'].unique()

    results = []
    for subject in subject_domains:
        document = df.loc[df['Subject Domain'] == subject]['Subject Domain Description'].values[0]
        stemmed_document = stem_entire_document(document)
        top_k_keywords = get_top_k_keywords(stemmed_document, type, k)
        results.append([subject, top_k_keywords])
    
    df_result = pd.DataFrame(results, columns=['Subject Domain', 'Top K Keywords'])
    return df_result

# %% [markdown]
# ### Model 1: TF-IDF

# %%
# helper function
# identity tokenizer that returns the original text (for tfidf)
def identity_tokenizer(text):
    return text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def get_top_k_keywords_tfidf(documents, k=10):

    # define tfidf vectorizer
    tfidf = TfidfVectorizer(tokenizer=identity_tokenizer, lowercase=False)
    transformed_documents = tfidf.fit_transform(documents)

    feature_array = tfidf.get_feature_names()
    tfidf_scores = sorted(list(zip(
        tfidf.get_feature_names(), transformed_documents.sum(0).getA1())), key=lambda x: x[1], reverse=True)[:k]

    idf_scores = sorted(list(zip(feature_array,tfidf.idf_,)), key = lambda x: x[1], reverse=True)[:k]

    print(tfidf_scores)

# %%
documents = df_course_description.loc[df_course_description['Subject Domain'] == 'Chemistry']['Course Description']
documents = documents.apply(preprocess)
get_top_k_keywords_tfidf(documents, 20)
# Out:
# [('chem', 11.832816235278253), ('chemistry', 8.09839277236706), ('student', 6.002582489182729), ('course', 5.003532047836422), ('organic', 4.9924757913933835), ('credit', 4.394229631219657), ('hour', 4.31921569572002), ('chemical', 4.301486384398401), ('graduate', 4.248369656505552), ('prerequisite', 4.1882763263630265), ('may', 3.74055485770705), ('inorganic', 3.0387652530800136), ('material', 2.71395051191926), ('undergraduate', 2.684230552624926), ('laboratory', 2.6444490418073463), ('see', 2.586844236222122), ('technique', 2.559782959528158), ('required', 2.556057896594594), ('synthesis', 2.3844607092227665), ('structure', 2.331992337888255)]

# %% [markdown]
# ### Model 2: TextRank

# %%
# get top 10 keywords using TextRank
top_k_textrank = get_top_k_keywords_for_all_subjects(df_subject_domain_descriptions, 'textrank', 10)

# %%
top_k_textrank
# Out:
#                     Subject Domain  \
# 0                 Computer Science
# 1              Biomedical Sciences
# 2              Biological Sciences
# 3                          English
# 4                        Chemistry
# 5                          Chinese
# 6                   Earth Sciences
# 7                      Mathematics
# 8                          Physics
# 9                          Faculty
# 10  Statistics & Actuarial Science
# 11                         Biology
# 12             Nutritional Science
#
#                                        Top K Keywords
# 0   [data, student, cours comput program, informat...
# 1   [protein, student, cours, molecular, biochemis...
# 2   [cours, biology, biological, process, environm...
# 3   [student, scienc, learn, cours, present, langu...
# 4   [chemistry, chemistri equival, cours aim provi...
# 5   [messag, student, write, techniqu, report, pre...
# 6   [student, environ, earth, geology manag, impac...
# 7   [theorems, mathematics, applic, applications, ...
# 8   [cours, basic physic, theori, topic includ, eq...
# 9   [student, students, science, sciences, cours, ...
# 10  [model, statist, data analysi, estim, estimati...
# 11  [student, biology, cours develop, graduat, dis...
# 12  [food, fshn, prerequisit, cours, product, prod...

# %%
# save TextRank top 10 to local
top_k_textrank.to_csv('subject-skills-results/top-10-textrank.csv')

# %% [markdown]
# ### Model 3: YAKE!

# %%
top_k_yake = get_top_k_keywords_for_all_subjects(df_subject_domain_descriptions, 'yake', k=20)

# %%
top_k_yake
# Out:
#                     Subject Domain  \
# 0                 Computer Science
# 1              Biomedical Sciences
# 2              Biological Sciences
# 3                          English
# 4                        Chemistry
# 5                          Chinese
# 6                   Earth Sciences
# 7                      Mathematics
# 8                          Physics
# 9                          Faculty
# 10  Statistics & Actuarial Science
# 11                         Biology
# 12             Nutritional Science
#
#                                        Top K Keywords
# 0   [hour, cours, graduat, topic, inform, credit, ...
# 1   [protein, student, cours, molecular, biochemis...
# 2   [student, cours, biolog, food, major, scienc, ...
# 3   [present, studi, cours, languag, student, skil...
# 4   [chemistri, chem, cours, student, chemic, orga...
# 5   [email, messag, techniqu, write, style, rhetor...
# 6   [hour, geol, prerequisit, student, geolog, env...
# 7   [math, hour, prerequisit, cours, linear, diffe...
# 8   [elect, cours, physic, astronomi, theme, numer...
# 9   [student, cours, scienc, research, develop, di...
# 10  [model, statist, cours, stat, student, data, a...
# 11  [hour, student, graduat, credit, prerequisit, ...
# 12  [hour, fshn, food, graduat, nutrit, prerequisi...

# %%
# convert the top 20 keywords for each subject domain to a dictionary
top_k_yake_dict = top_k_yake.set_index('Subject Domain')['Top K Keywords'].to_dict()

# %%
# save the dictionary to json
import json
with open('data/subject_domain_keywords_top_20_yake_dict.json', 'w') as fp:
    json.dump(top_k_yake_dict, fp)

# %%
data
# Out:
# {'Top K Keywords': {'Computer Science': ['hour',
#    'cours',
#    'graduat',
#    'topic',
#    'inform',
#    'credit',
#    'quantum',
#    'comput',
#    'student',
#    'data',
#    'math',
#    'prerequisit',
#    'includ',
#    'profession',
#    'design',
#    'program',
#    'learn',
#    'develop',
#    'scienc',
#    'undergradu'],
#   'Biomedical Sciences': ['protein',
#    'student',
#    'cours',
#    'molecular',
#    'biochemistri',
#    'sequenc',
#    'cell',
#    'basic',
#    'signal',
#    'structur',
#    'provid',
#    'biolog',
#    'gene',
#    'studi',
#    'analysi',
#    'acid',
#    'method',
#    'metabol',
#    'scienc',
#    'life'],
#   'Biological Sciences': ['student',
#    'cours',
#    'biolog',
#    'food',
#    'major',
#    'scienc',
#    'provid',
#    'environment',
#    'ecolog',
#    'studi',
#    'process',
#    'field',
#    'system',
#    'understand',
#    'nutrit',
#    'introduc',
#    'chang',
#    'knowledg',
#    'basic',
#    'topic'],
#   'English': ['present',
#    'studi',
#    'cours',
#    'languag',
#    'student',
#    'skill',
#    'learn',
#    'profession',
#    'commun',
#    'academ',
#    'rhetor',
#    'spoken',
#    'scienc',
#    'main',
#    'compon',
#    'explain',
#    'written',
#    'develop',
#    'oral',
#    'case'],
#   'Chemistry': ['chemistri',
#    'chem',
#    'cours',
#    'student',
#    'chemic',
#    'organ',
#    'hour',
#    'reaction',
#    'credit',
#    'prerequisit',
#    'graduat',
#    'principl',
#    'bond',
#    'provid',
#    'structur',
#    'aim',
#    'materi',
#    'concept',
#    'theori',
#    'includ'],
#   'Chinese': ['email',
#    'messag',
#    'techniqu',
#    'write',
#    'style',
#    'rhetor',
#    'report',
#    'chines',
#    'student',
#    'reader-bas',
#    'grammar',
#    'letter',
#    'announc',
#    'notic',
#    'brochur',
#    'leaflet',
#    'addit',
#    'document',
#    'present',
#    'vocabulari'],
#   'Earth Sciences': ['hour',
#    'geol',
#    'prerequisit',
#    'student',
#    'geolog',
#    'environment',
#    'earth',
#    'cours',
#    'graduat',
#    'scienc',
#    'field',
#    'resourc',
#    'studi',
#    'credit',
#    'nre',
#    'climat',
#    'natur',
#    'map',
#    'rock',
#    'appli'],
#   'Mathematics': ['math',
#    'hour',
#    'prerequisit',
#    'cours',
#    'linear',
#    'differenti',
#    'mathemat',
#    'student',
#    'equat',
#    'credit',
#    'theorem',
#    'topic',
#    'function',
#    'applic',
#    'integr',
#    'instructor',
#    'theori',
#    'basic',
#    'algebra',
#    'space'],
#   'Physics': ['elect',
#    'cours',
#    'physic',
#    'astronomi',
#    'theme',
#    'numer',
#    'phi',
#    'introduc',
#    'essenti',
#    'postgradu',
#    'student',
#    'plan',
#    'disciplin',
#    'pursu',
#    'analyt',
#    'topic',
#    'studi',
#    'project',
#    'prerequisit',
#    'minor'],
#   'Faculty': ['student',
#    'cours',
#    'scienc',
#    'research',
#    'develop',
#    'differ',
#    'work',
#    'opportun',
#    'provid',
#    'univers',
#    'busi',
#    'scientif',
#    'skill',
#    'market',
#    'practic',
#    'staff',
#    'learn',
#    'conduct',
#    'entrepreneuri',
#    'supervis'],
#   'Statistics & Actuarial Science': ['model',
#    'statist',
#    'cours',
#    'stat',
#    'student',
#    'data',
#    'analysi',
#    'hour',
#    'topic',
#    'method',
#    'risk',
#    'prerequisit',
#    'estim',
#    'math',
#    'problem',
#    'process',
#    'probabl',
#    'test',
#    'graduat',
#    'includ'],
#   'Biology': ['hour',
#    'student',
#    'graduat',
#    'credit',
#    'prerequisit',
#    'repeat',
#    'grade',
#    'consent',
#    'mcb',
#    'instructor',
#    'approv',
#    'cours',
#    'biolog',
#    'maximum',
#    'undergradu',
#    'topic',
#    'includ',
#    'enrol',
#    'research',
#    'engin'],
#   'Nutritional Science': ['hour',
#    'fshn',
#    'food',
#    'graduat',
#    'nutrit',
#    'prerequisit',
#    'credit',
#    'scienc',
#    'repeat',
#    'cours',
#    'undergradu',
#    'topic',
#    'student',
#    'product',
#    'special',
#    'approv',
#    'term',
#    'grade',
#    'manag',
#    'letter']}}

# %%
# save YAKE top 20 to csv
top_k_yake.to_csv('subject-skills-results/top-20-yake.csv')

# %% [markdown]
# ### Model 4: KeyBERT

# %%
top_k_keybert = get_top_k_keywords_for_all_subjects(df_subject_domain_descriptions, 'keybert', k=10)

# %%
top_k_keybert
# Out:
#                     Subject Domain  \
# 0                 Computer Science
# 1              Biomedical Sciences
# 2              Biological Sciences
# 3                          English
# 4                        Chemistry
# 5                          Chinese
# 6                   Earth Sciences
# 7                      Mathematics
# 8                          Physics
# 9                          Faculty
# 10  Statistics & Actuarial Science
# 11                         Biology
# 12             Nutritional Science
#
#                                        Top K Keywords
# 0   [(python, 0.4429), (javascript, 0.3521), (biol...
# 1   [(biotechnolog, 0.6446), (biochemistry, 0.6398...
# 2   [(biotechnologypract, 0.5221), (biochemistry, ...
# 3   [(presentationstud, 0.6183), (examin, 0.5725),...
# 4   [(chem1042, 0.4485), (hour, 0.4073), (august, ...
# 5   [(email, 0.3805), (techniqu, 0.306), (linguist...
# 6   [(geotechn, 0.6321), (paleoproterozo, 0.5872),...
# 7   [(math3943, 0.5118), (riemannian, 0.4964), (co...
# 8   [(cosmolog, 0.5392), (biophys, 0.4803), (calcu...
# 9   [(entrepreneurship, 0.4537), (biotechnolog, 0....
# 10  [(seminar, 0.5212), (biolog, 0.4938), (philoso...
# 11  [(biotechnolog, 0.6433), (microbiolog, 0.6262)...
# 12  [(foodborn, 0.5354), (foodservic, 0.5248), (ca...

# %%
# save KeyBERT top 10 to local
top_k_keybert.to_csv('subject-skills-results/top-10-keybert.csv')
