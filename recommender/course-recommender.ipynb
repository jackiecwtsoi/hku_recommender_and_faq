# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Raw Datasets

# %%
# define dataset path
CURRICULUM_DATA_PATH = '../crawlers/closed-ended/curriculum-crawlers/data/'

# %%
# load cs recommender datasets
df_cs_all = pd.read_csv(CURRICULUM_DATA_PATH + 'df_cs_all_course_details_prelim.csv', index_col = 0) # all cs course details
df_cs_profs = pd.read_csv(CURRICULUM_DATA_PATH + 'df_cs_courses_and_professors.csv', index_col = 0) # cs course professors

# %%
df_cs_all.head(3)
# Out:
#    Academic Year  No. of credit(s)  Lecture  Lab session Pre-requisite(s)  \
# 0           2022                 6     32.5          6.5              NaN
# 1           2022                 6     32.5          6.5              NaN
# 2           2022                 6      NaN          NaN              NaN
#
#   Co-requisite(s) Mutually exclusive with  Remarks Course Code  \
# 0             NaN    ENGG1111 or ENGG1330      NaN   COMP1117A
# 1             NaN    ENGG1111 or ENGG1330      NaN   COMP1117B
# 2             NaN    COMP1117 or ENGG1111      NaN   ENGG1330A
#
#                                         Course Title  \
# 0  Computer Programming (ActSc, AppAI, DA, IS, Mi...
# 1  Computer Programming (Quant Fin, DA, Minor, 2n...
# 2                   Computer Programming I (A1 - M2)
#
#                                   Course Description  \
# 0  This is an introductory course in computer pro...
# 1  This is an introductory course in computer pro...
# 2  This is an introductory course designed for fi...
#
#                                    Learning Outcomes  \
# 0  [Computational mind]  Able to identify possibl...
# 1  [Computational mind]  Able to identify possibl...
# 2  [Computational mind] Able to identify possible...
#
#    Continuous Assessment Weighting in final course grade (%)  \
# 0                                               50.0
# 1                                               50.0
# 2                                               70.0
#
#    Written Examination Weighting in final course grade (%)  Tutorial  Other  \
# 0                                               50.0             NaN    NaN
# 1                                               50.0             NaN    NaN
# 2                                               30.0            26.0   13.0
#
#   Recommended Learning Hours  Self-study & practical modules Choi Loretta
# 0                        NaN                             NaN          NaN
# 1                        NaN                             NaN          NaN
# 2                        NaN                             NaN          NaN

# %%
# load science recommender datasets
df_science_all = pd.read_csv(CURRICULUM_DATA_PATH + 'df_science_all_course_details.csv', index_col = 0) # all science course details
df_science_profs = pd.read_csv(CURRICULUM_DATA_PATH + 'df_science_courses_and_professors.csv', index_col = 0) # science course professors
df_science_meta = pd.read_csv(CURRICULUM_DATA_PATH + 'df_science_courses_pre.csv', index_col = 0) # meta table

# %% [markdown]
# ## Process Raw Datasets

# %%
# add necessary columns to the 'df_cs_all' dataset
df_cs_all['Offering Department'] = 'Computer Science'

# %%
# extract course content related columns for cs
df_cs_content = df_cs_all[[
    'Course Code', 'Course Title', 'Course Description', 'Learning Outcomes'
]]

# %%
df_cs_content.head()
# Out:
#   Course Code                                       Course Title  \
# 0   COMP1117A  Computer Programming (ActSc, AppAI, DA, IS, Mi...
# 1   COMP1117B  Computer Programming (Quant Fin, DA, Minor, 2n...
# 2   ENGG1330A                   Computer Programming I (A1 - M2)
# 3   ENGG1340A                            Computer Programming II
# 4   ENGG1340B                            Computer Programming II
#
#                                   Course Description  \
# 0  This is an introductory course in computer pro...
# 1  This is an introductory course in computer pro...
# 2  This is an introductory course designed for fi...
# 3  This course covers intermediate to advanced co...
# 4  This course covers intermediate to advanced co...
#
#                                    Learning Outcomes
# 0  [Computational mind]  Able to identify possibl...
# 1  [Computational mind]  Able to identify possibl...
# 2  [Computational mind] Able to identify possible...
# 3  [Programming environment and technologies] Abl...
# 4  [Programming environment and technologies] Abl...

# %%
# add necessary columns to the 'df_science_all' dataset
df_science_all['Course Title'] = df_science_meta['Title'] # add course title column
df_science_all['Course Description'] = df_science_all['Course Contents & Topics'] + ' ' + df_science_all['Course Objectives']

# %%
# extract course content related columns for science
df_science_content = df_science_all[[
    'Course Code', 'Course Title', 'Course Description'
]]
df_science_content['Learning Outcomes'] = df_science_all['Course Learning Outcomes']
# Out:
# c:\Users\Kackie\anaconda3\envs\DataScience\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
df_science_content.head()
# Out:
#   Course Code                                       Course Title  \
# 0    BIOC1600                       Perspectives in biochemistry
# 1    BIOC2600                                 Basic biochemistry
# 2    BIOC3601                                   Basic metabolism
# 3    BIOC3604  Essential techniques in biochemistry and molec...
# 4    BIOC3605                            Sequence bioinformatics
#
#                                   Course Description  \
# 0  A Biochemical Perspective on the Basic Science...
# 1  Structure and functions of carbohydrates, lipi...
# 2  This course focuses on the central metabolic p...
# 3  Basic concepts in experimental science; writin...
# 4  This course will introduce and discuss the fol...
#
#                                    Learning Outcomes
# 0  describe the basics of biomolecular structure ...
# 1  relate the structures to functions of major bi...
# 2  achieve a vigorous intellectual appreciation o...
# 3  describe and explain the principles underlying...
# 4  search and retrieve sequence data from biologi...

# %%
# combine both cs and science datasets for course content info
df_course_content = df_cs_content.append(df_science_content)
df_course_content = df_course_content.reset_index(drop = True)

# %%
df_course_content
# Out:
#     Course Code                                       Course Title  \
# 0     COMP1117A  Computer Programming (ActSc, AppAI, DA, IS, Mi...
# 1     COMP1117B  Computer Programming (Quant Fin, DA, Minor, 2n...
# 2     ENGG1330A                   Computer Programming I (A1 - M2)
# 3     ENGG1340A                            Computer Programming II
# 4     ENGG1340B                            Computer Programming II
# ..          ...                                                ...
# 425    CCST9051  What are We Made of - the Fundamental Nature o...
# 426    CCST9054                  War, Peace, and the Natural World
# 427    CCST9056             The Force is with You: How Things Work
# 428    CCST9067                 Leaving Earth: Our Future in Space
# 429    CCST9068       Artificial Intelligence: Utopia or Dystopia?
#
#                                     Course Description  \
# 0    This is an introductory course in computer pro...
# 1    This is an introductory course in computer pro...
# 2    This is an introductory course designed for fi...
# 3    This course covers intermediate to advanced co...
# 4    This course covers intermediate to advanced co...
# ..                                                 ...
# 425                                                NaN
# 426                                                NaN
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
#
#                                      Learning Outcomes
# 0    [Computational mind]  Able to identify possibl...
# 1    [Computational mind]  Able to identify possibl...
# 2    [Computational mind] Able to identify possible...
# 3    [Programming environment and technologies] Abl...
# 4    [Programming environment and technologies] Abl...
# ..                                                 ...
# 425                                                NaN
# 426                                                NaN
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
#
# [430 rows x 4 columns]

# %% [markdown]
# ## Save Processed Dataset

# %%
# save the processed dataset under the 'ontology-based-recommender/data' folder
df_course_content.to_csv('data/df_course_content.csv')

# %% [markdown]
# # Experiments for CourseContent

# %%
df_course_content = pd.read_csv('data/df_course_content.csv', index_col=0)

# %%
df_course_content
# Out:
#     Course Code                                       Course Title  \
# 0     COMP1117A  Computer Programming (ActSc, AppAI, DA, IS, Mi...
# 1     COMP1117B  Computer Programming (Quant Fin, DA, Minor, 2n...
# 2     ENGG1330A                   Computer Programming I (A1 - M2)
# 3     ENGG1340A                            Computer Programming II
# 4     ENGG1340B                            Computer Programming II
# ..          ...                                                ...
# 425    CCST9051  What are We Made of - the Fundamental Nature o...
# 426    CCST9054                  War, Peace, and the Natural World
# 427    CCST9056             The Force is with You: How Things Work
# 428    CCST9067                 Leaving Earth: Our Future in Space
# 429    CCST9068       Artificial Intelligence: Utopia or Dystopia?
#
#                                     Course Description  \
# 0    This is an introductory course in computer pro...
# 1    This is an introductory course in computer pro...
# 2    This is an introductory course designed for fi...
# 3    This course covers intermediate to advanced co...
# 4    This course covers intermediate to advanced co...
# ..                                                 ...
# 425                                                NaN
# 426                                                NaN
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
#
#                                      Learning Outcomes
# 0    [Computational mind]  Able to identify possibl...
# 1    [Computational mind]  Able to identify possibl...
# 2    [Computational mind] Able to identify possible...
# 3    [Programming environment and technologies] Abl...
# 4    [Programming environment and technologies] Abl...
# ..                                                 ...
# 425                                                NaN
# 426                                                NaN
# 427                                                NaN
# 428                                                NaN
# 429                                                NaN
#
# [430 rows x 4 columns]

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk import word_tokenize
from nltk.corpus import stopwords
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Kackie\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kackie\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from scipy import spatial

# %% [markdown]
# ## Helper Functions

# %%
# helper function
# return: LIST of tokenized words
def preprocess(text, with_stopwords=False):
    text = text.lower()
    words = word_tokenize(text)
    words = [word for word in words if word.isalpha()]
    if with_stopwords==False:
        stop_words = set(stopwords.words('english'))
        words = [word for word in words if not word in stop_words]
    
    return words

# %%
# helper function
# return: word embeddings MATRIX
def get_vector(text, model, with_stopwords=False):
    return np.sum(np.array([model[i] for i in preprocess(text, with_stopwords=with_stopwords)]), axis=0)

# %%
# helper function
# calculate cosine similarity for a given student provided info text with a text from our database
# return: FLOAT representing the similarity score
def get_similarity_score(student_info, text, model, with_stopwords):
    similarity = 1 - spatial.distance.cosine(
        get_vector(student_info, model, with_stopwords),
        get_vector(text, model, with_stopwords)
    )
    return similarity

# %%
# helper function
# get cosine similarities of a specific query against all job descriptions
# return: dataframe with new column 'Cosine Similarity'
def get_similarities(student_info, df, model, with_stopwords=False, n=-1):
    df_result = df.copy()
    columns_to_consider = ['Learning Outcomes', 'Course Description', 'Course Title'] # TODO: should we consider course title?
    for column_name in columns_to_consider:
        similarities = []
        for text in df_result[column_name]:
            try:
                similarity = get_similarity_score(student_info, text, model, with_stopwords)
                similarities.append(similarity)
            except:
                similarities.append(0)
                continue
        df_result['Cosine Similarity for ' + column_name] = similarities

    df_result.insert(0, 'Student Provided Info', student_info)

    # get the final cosine similarity based on weights
    df_result['Final Cosine Similarity'] = df_result['Cosine Similarity for Learning Outcomes']*0.6 + df_result['Cosine Similarity for Course Description']*0.3 + df_result['Cosine Similarity for Course Title']*0.1

    # get the top n results (n=-1 means all results)
    df_result = df_result.sort_values(by='Final Cosine Similarity', ascending=False).head(n)

    return df_result

# %%
# helper function
# get cosine similarities for ALL student provided info texts in our testing dataset
# return: DATAFRAME
def get_similarities_for_test_data(df_course_content, df_test, model, with_stopwords=False, n=-1):
    df_result = pd.DataFrame()
    for i, student_provided_info in enumerate(df_test['student_provided_info']):
        df = get_similarities(
            student_provided_info,
            df_course_content,
            model, with_stopwords=with_stopwords,
            n=n
        )
        df.insert(1, 'Target Course Code', df_test['target_course_code'][i])

        df_result = df_result.append(df)

    return df_result

# %% [markdown]
# ## Testing Dataset

# %%
# load self-made testing dataset
df_course_content_test = pd.read_csv('data/course_content_testing_data.csv')

# %%
df_course_content_test
# Out:
#                                student_provided_info  \
# 0  I want to learn about programming but I am a b...
# 1  I'm not familiar to databases but would like l...
# 2     I am interested in both biology and chemistry.
# 3  I am not good at math but I want to be in the ...
# 4               I am interested in the solar system.
# 5  Interested in fintech, especially trading algo...
# 6  I want to know more Java and practice to write...
# 7     Any common core courses about the environment?
# 8                                     I like robots.
# 9                I wanna learn about earth sciences.
#
#   student_profile_equivalent          intent target_course_code
# 0              interest_area  recommendation          COMP1117A
# 1              interest_area  recommendation          COMP3278A
# 2              interest_area  recommendation           BIOC1600
# 3              interest_area  recommendation           MATH1011
# 4              interest_area  recommendation           PHYS1650
# 5              interest_area  recommendation           FITE1010
# 6              interest_area  recommendation           COMP3330
# 7              interest_area  recommendation           CCST9013
# 8              interest_area  recommendation           COMP3356
# 9              interest_area  recommendation           EASC1401

# %% [markdown]
# ## Models

# %% [markdown]
# ### Model 1: Word2Vec (pre-trained on Google News 300)

# %%
import gensim.downloader as api

# define word2vec model
model_w2v = api.load('word2vec-google-news-300')

# %%
get_similarities('I want to learn about programming but I am a beginner', df_course_content, model_w2v, False, 5)
# Out:
#                                 Student Provided Info Course Code  \
# 21  I want to learn about programming but I am a b...   COMP2396B
# 20  I want to learn about programming but I am a b...   COMP2396A
# 51  I want to learn about programming but I am a b...    COMP3259
# 62  I want to learn about programming but I am a b...    COMP3329
# 7   I want to learn about programming but I am a b...   FITE2000A
#
#                                  Course Title  \
# 21       Object-oriented Programming and Java
# 20  Object-oriented Programming and Java (CS)
# 51        Principles of Programming Languages
# 62       Computer Game Design and Programming
# 7          Foundations of FinTech Programming
#
#                                    Course Description  \
# 21  Introduction to object-oriented programming; a...
# 20  Introduction to object-oriented programming; a...
# 51  Syntax and semantics specification; data types...
# 62  This course introduces the concepts and techni...
# 7   This course introduces concepts and applicatio...
#
#                                     Learning Outcomes  \
# 21  [Object-oriented Programming] Be able to under...
# 20  [Object-oriented Programming] Be able to under...
# 51  [Programming languages fundamentals] Be able t...
# 62  [implement a workable game in particular platf...
# 7   [Basic data structures] To learn and appreciat...
#
#     Cosine Similarity for Learning Outcomes  \
# 21                                 0.626530
# 20                                 0.626530
# 51                                 0.640547
# 62                                 0.588019
# 7                                  0.583533
#
#     Cosine Similarity for Course Description  \
# 21                                  0.517905
# 20                                  0.517905
# 51                                  0.437723
# 62                                  0.515196
# 7                                   0.444559
#
#     Cosine Similarity for Course Title  Final Cosine Similarity
# 21                            0.471758                 0.578465
# 20                            0.402898                 0.571579
# 51                            0.501147                 0.565760
# 62                            0.537100                 0.561080
# 7                             0.449941                 0.528481

# %%
get_similarities_for_test_data(df_course_content, df_course_content_test, model_w2v, with_stopwords=False, n=5).to_csv('test.csv')
# Out:
# c:\Users\Kackie\anaconda3\envs\DataScience\lib\site-packages\scipy\spatial\distance.py:699: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
# save the model
model_w2v.save('models/w2v_google_news_300.model')

# %% [markdown]
# ### Model 2:

# %%
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api
from multiprocessing import cpu_count

# %%
# load the corpus from the gensim repo
corpus_wiki_english = api.load('wiki-english-20171001')
# Out:
#  Part 1/4 [==================================================] 100.0% 1950.0/1950.0MB downloaded
#  Part 2/4 [==================================================] 100.0% 1950.0/1950.0MB downloaded
#  Part 3/4 [==================================================] 100.0% 1950.0/1950.0MB downloaded
#  Part 4/4 [==================================================] 100.0% 364.2/364.2MB downloaded

# %%
model_w2v_wiki_english = Word2Vec(corpus_wiki_english, workers = cpu_count())

# %%
model_w2v_wiki_english.save('models/w2v_wiki_english.model')
